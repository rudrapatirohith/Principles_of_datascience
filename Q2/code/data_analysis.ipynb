# %%
import pandas as pd

# %%
# importing clean data for analysis

# %%
data_frame = pd.read_csv('C:/Users/rudra/OneDrive/Desktop/PDS/Q2/StudentsPerformance_clean.csv')
print(data_frame.to_string())
# Out:
#      Unnamed: 0  gender race/ethnicity parental level of education         lunch test preparation course  math score  reading score  writing score
# 0             0  female        group B           bachelor's degree      standard                    none          72             72             74
# 1             1  female        group C                some college      standard               completed          69             90             88
# 2             2  female        group B             master's degree      standard                    none          90             95             93
# 3             3    male        group A          associate's degree  free/reduced                    none          47             57             44
# 4             4    male        group C                some college      standard                    none          76             78             75
# ...

# %%
# creating new column Average by taking the average of all the available scores

# %%
data_frame["Average_score"]=(data_frame["math score"]+data_frame["reading score"]+data_frame["writing score"])/3
print(data_frame["Average_score"])
# Out:
# 0      72.666667
# 1      82.333333
# 2      92.666667
# 3      49.333333
# 4      76.333333
#          ...
# 995    94.000000
# 996    57.333333
# 997    65.000000
# 998    74.333333
# 999    83.000000
# Name: Average_score, Length: 1000, dtype: float64

# %%
def Grade(Average_score):
    if (Average_score >= 95):return 'O'
    if (Average_score >= 81):return 'A'
    if (Average_score >= 71):return 'B'
    if (Average_score >= 61):return 'C'
    if (Average_score >= 51):return 'D'
    if (Average_score >= 41):return 'E'
    else: return 'F'
    
data_frame["grade"] = data_frame.apply(lambda x : Grade(x["Average_score"]),axis=1)

# %%
data_frame
# Out:
#      Unnamed: 0  gender race/ethnicity parental level of education  \
# 0             0  female        group B           bachelor's degree
# 1             1  female        group C                some college
# 2             2  female        group B             master's degree
# 3             3    male        group A          associate's degree
# 4             4    male        group C                some college
# ..          ...     ...            ...                         ...
# 995         995  female        group E             master's degree
# 996         996    male        group C                 high school
# 997         997  female        group C                 high school
# 998         998  female        group D                some college
# 999         999  female        group D                some college
#
#             lunch test preparation course  math score  reading score  \
# 0        standard                    none          72             72
# ...

# %%
sorted_df = data_frame.sort_values(by='Average_score',ascending = False)

# %%
# using Seaborn for analysis

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
grades = sorted_df['grade']
value_counts = grades.value_counts()
plt.figure(figsize=(10, 6))
sns.barplot(x=value_counts.index, y=value_counts.values, color="grey",order=["O", "A", "B", "C", "D", "E", "F"])
plt.xlabel("Grade")
plt.ylabel("Count")
plt.title("Bar Chart showing grade count")
plt.show()

# %% [raw]
# The above bar chart  bar chart showing the count of each grade, provides insights into the distribution of grades in dataset. This helps us see which grades are common and which are rare.
# From the chart we can see B and C grades are most common and it suggests some students may have struggled

# %%
plt.figure(figsize=(8, 8))
plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%', colors=['blue', 'green', 'red', 'purple', 'orange', 'pink', 'brown'])
plt.title("Pie Chart of Grade Frequencies")
plt.show()

# %% [raw]
# The pie chart compares students' grades by showing each grade as a slice of the pie. The bigger the slice, the more students received that grade. It helps us quickly see which grades are most common and least common among students.From above we can see more than 50% of students received either B or C and O grade is having the least percentage that is only 2.2%

# %%
plt.figure(figsize=(10, 6))
ax = sns.countplot(y="grade", hue="gender", data=data_frame, order=["O", "A", "B", "C", "D", "E", "F"])

# Customize labels and title
ax.set_xlabel("Count")
ax.set_ylabel("Grade")
ax.set_title("Countplot of Grades by Gender")

# Save the figure to a file
plt.savefig("C:/Users/rudra/OneDrive/Desktop/PDS/Q2/Analysis_Grade_gender.png")

# Show the plot 
plt.show()

# %% [raw]
# This above chart shows how many students of each gender received each grade. The bars represent the counts, with different colors for male and female students. It helps compare grade distributions between genders.and From above chart we can see that female students performed much better than male students.

# %%
plt.figure(figsize=(10, 6))
ax = sns.countplot(y="grade", hue="race/ethnicity", data=data_frame, order=["O", "A", "B", "C", "D", "E", "F"])

# Customize labels and title
ax.set_xlabel("Count")
ax.set_ylabel("Grade")
ax.set_title("Countplot of Grades by race/ethnicity")

# Save the figure to a file
plt.savefig("C:/Users/rudra/OneDrive/Desktop/PDS/Q2/Analysis_Grade_race.png")

# Show the plot 
plt.show()

# %% [raw]
# This chart displays how grades are distributed among various racial or ethnic groups. The bars represent the number of students with each grade, with different colors indicating different racial backgrounds. It helps compare grade distributions across these groups.

# %%
g = sns.pairplot(data_frame, hue='test preparation course', 
                 vars=['Average_score', 'math score', 'writing score', 'reading score'])

# Customize the plot (e.g., labels and title)
g.fig.suptitle("Pairplot of Scores vs. Average Score by Test Preparation Course", y=1.02)

# Save the plot to a file
plt.savefig("C:/Users/rudra/OneDrive/Desktop/PDS/Q2/Analysis_test_prepartion.png")

# Show the plot 
plt.show()

# %% [raw]
# This chart compares how students' test scores in various subjects (math, writing, reading) relate to their average score. Different colors indicate whether students took a test preparation course. It helps us see if test preparation affects students' performance in different subjects.
